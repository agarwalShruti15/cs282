# %% [markdown]
# #

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from video2tfrecord import convert_videos_to_tfrecord
from test import *
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
path='/Users/dsrincon/Dropbox/Personal/EDU/Posgrado/masters_usa/MIMS/2019-I/cs282_deep_neural_networks/assignments/project/cs282/models/raw_pixels/batch_1_of_1.tfrecords'
filenames=[path]
n_frames=10
num,videos=get_number_of_records(filenames, n_frames)

# %%
print(num)
print(len(videos))
print(type(videos[0]))
print(videos[0].shape)
# Out:
# 1
# 1
# <class 'numpy.ndarray'>
# (10, 128, 128, 3)

# %%
plt.imshow(videos[0][8])
plt.show()
