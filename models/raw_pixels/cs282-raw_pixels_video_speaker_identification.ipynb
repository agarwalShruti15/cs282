# %% [markdown]
# #

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from video2tfrecord import convert_videos_to_tfrecord
from test import *
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
path='/home/ubuntu/fakebusters/data/train/tf_records/putin/batch_1_of_1.tfrecords'
filenames=[path]
n_frames=32
num,videos=get_number_of_records(filenames, n_frames)

# %%
print(num)
print(len(videos))
print(type(videos[0]))
print(np.array(videos).shape)
# Out:
# 179
# 179
# <class 'numpy.ndarray'>
# (179, 32, 70, 70, 3)

# %%
plt.imshow(videos[60][30])
plt.show()
